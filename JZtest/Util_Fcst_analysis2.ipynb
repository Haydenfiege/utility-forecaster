# %%
import pandas as pd
from weather_scrape import *
from electricity_scrape import *

# %%
#input parameters
#aeso inputs
startdate = '2021-03-01'
enddate = '2021-03-30'
dateformat = '%Y-%m-%d'
contenttype = 'html'
#additional weather inputs city and timeframe 1 = hourly, 2 = daily
city = 'yyc'

# %%
#aeso tables that can currently be scraped by function
dl_tables = ['DdsChargeSummary', 'HistoricalPoolPrice', 'ASPStandbyOperatingReservePrice',
             'ASPActivation', 'ASPActiveOperatingReservePrice', 'ActualForecastWMRQH', 
             'DailyAveragePoolPrice', 'HistoricalSystemMarginalPrice', 'RegulatingReserves']

# %%
#scrape all available tables for defined time range
for t in dl_tables:
    #dataframe name is prefixed with "aeso_"
    df_name = 'aeso_'+t
    exec(df_name +" = aeso_download_range('" + t + "', contenttype, startdate, enddate, dateformat)")
# Out:
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:12.771764 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/DdsChargeSummaryReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:13.482136 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/HistoricalPoolPriceReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:13.753497 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/ASPStandbyOperatingReservePriceReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:13.926035 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/ASPActivationReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:14.080626 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/ASPActiveOperatingReservePriceReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:14.239178 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/ActualForecastWMRQHReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:14.543365 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/DailyAveragePoolPriceReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:14.728868 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/HistoricalSystemMarginalPriceReportServlet?beginDate=03012021&endDate=03122021&contentType=html
# date range <= 30 days, downloading
# converted date string from 2021-03-01 00:00:00 to datetime value 03012021
# converted date string from 2021-03-12 23:12:15.068981 to datetime value 03122021
# download url generated: http://ets.aeso.ca/ets_web/ip/Market/Reports/RegulatingReservesReportServlet?beginDate=03012021&endDate=03122021&contentType=html

# %%
#scrape hourly weather data for defined timeframe
weather_hourly = weather_dl_range(startdate, enddate, dateformat, city, 1, clean=True)
#scrape daily weather data for defined timeframe
weather_daily = weather_dl_range(startdate, enddate, dateformat, city, 2, clean=True)
# Out:
# Getting data for YYC, station ID 50430
# downloading hourly data for year-month: 2021-1
# sleep for 3 seconds
# downloading hourly data for year-month: 2021-2
# sleep for 1 seconds
# downloading hourly data for year-month: 2021-3
# sleep for 1 seconds
# downloading hourly data for year-month: 2021-4
# sleep for 4 seconds
# downloading hourly data for year-month: 2021-5
# sleep for 3 seconds
# downloading hourly data for year-month: 2021-6
# sleep for 1 seconds
# downloading hourly data for year-month: 2021-7
# sleep for 2 seconds
# downloading hourly data for year-month: 2021-8
# sleep for 3 seconds
# downloading hourly data for year-month: 2021-9
# sleep for 3 seconds
# downloading hourly data for year-month: 2021-10
# sleep for 3 seconds
# downloading hourly data for year-month: 2021-11
# sleep for 3 seconds
# downloading hourly data for year-month: 2021-12
# sleep for 2 seconds
# data for year 2021 downloaded
# sleep for 6 seconds
# C:\conda\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# Getting data for YYC, station ID 50430
# downloading daily data for year 2021
# data for year 2021 downloaded
# sleep for 7 seconds

# %%
#check the downloaded aeso table
for t in dl_tables:
    #dataframe name is prefixed with "aeso_"
    df_name = 'aeso_'+t
    print('Dataframe Name: '+df_name)
    exec("print(" + df_name + ".head())")
# Out:
# Dataframe Name: aeso_DdsChargeSummary
#         Date  HE  Total DDS Charges  Total Energy Production (MW)
# 0 2021-03-01   1                0.0                     6853.1251
# 1 2021-03-01   2                0.0                     6702.0216
# 2 2021-03-01   3                0.0                     6685.9491
# 3 2021-03-01   4                0.0                     6701.7511
# 4 2021-03-01   5                0.0                     6737.1460
# Dataframe Name: aeso_HistoricalPoolPrice
#             Date (HE)  Price ($)  30Ravg ($)  AIL Demand (MW)
# 0 2021-03-01 01:00:00      26.29      144.94           9649.0
# 1 2021-03-01 02:00:00      30.44      144.91           9540.0
# 2 2021-03-01 03:00:00      28.29      144.89           9521.0
# 3 2021-03-01 04:00:00      26.76      144.85           9538.0
# 4 2021-03-01 05:00:00      30.72      144.83           9562.0
# Dataframe Name: aeso_ASPStandbyOperatingReservePrice
#    Date_Date  Regulating Reserves_On Peak  Regulating Reserves_On Peak  \
# 0 2021-03-01                        $0.35                      $176.02
# 1 2021-03-02                        $1.71                      $141.32
# 2 2021-03-03                        $2.39                      $108.06
# 3 2021-03-04                        $3.62                      $318.02
# 4 2021-03-05                        $3.56                      $138.37
#
#    Regulating Reserves_On Peak  Regulating Reserves_On Peak  \
# 0                        $2.45                           40
# 1                        $6.15                           40
# 2                        $5.50                           40
# 3                       $13.98                           40
# 4                        $6.10                           40
#
#    Regulating Reserves_Off Peak  Regulating Reserves_Off Peak  \
# 0                         $0.91                        $60.06
# 1                         $0.07                        $76.84
# 2                         $1.05                        $38.85
# 3                        $16.37                        $80.75
# 4                         $4.18                        $42.12
#
#    Regulating Reserves_Off Peak  Regulating Reserves_Off Peak  \
# 0                         $3.20                            40
# 1                         $2.47                            40
# 2                         $2.46                            40
# 3                        $33.99                            40
# 4                         $8.96                            40
#
#   Spinning Reserves_On Peak  ... Spinning Reserves_Off Peak  \
# 0                     $5.12  ...                      $5.20
# 1                     $6.02  ...                      $6.15
# 2                     $5.65  ...                      $7.01
# 3                     $7.56  ...                      $5.39
# 4                     $5.71  ...                      $7.01
#
#   Spinning Reserves_Off Peak Supplemental Reserves_On Peak  \
# 0                        105                         $0.86
# 1                        105                         $1.12
# 2                        105                         $0.01
# 3                        105                         $0.01
# 4                        105                         $1.29
#
#   Supplemental Reserves_On Peak Supplemental Reserves_On Peak  \
# 0                        $62.82                        $10.91
# 1                        $58.43                         $9.31
# 2                        $51.48                         $6.00
# 3                        $59.58                         $7.01
# 4                        $51.52                         $7.01
#
#   Supplemental Reserves_On Peak Supplemental Reserves_Off Peak  \
# 0                            35                          $0.15
# 1                            35                          $0.23
# 2                            35                          $0.54
# 3                            35                          $0.74
# 4                            35                          $0.84
#
#   Supplemental Reserves_Off Peak Supplemental Reserves_Off Peak  \
# 0                         $26.06                          $3.01
# 1                         $17.93                          $2.29
# 2                         $18.79                          $2.62
# 3                         $17.03                          $2.60
# 4                         $25.90                          $3.62
#
#   Supplemental Reserves_Off Peak
# 0                             35
# 1                             35
# 2                             35
# 3                             35
# 4                             35
#
# [5 rows x 25 columns]
# Dataframe Name: aeso_ASPActivation
#   Service Level       Date  HE Reserve Type  Total Volume Activated (MW)  \
# 0       STANDBY 2021-03-02   1           RR                           15
# 1       STANDBY 2021-03-02   2           RR                           15
# 2       STANDBY 2021-03-02   3           RR                           15
# 3       STANDBY 2021-03-02   4           RR                           15
# 4       STANDBY 2021-03-02   5           RR                           15
#
#    Weighted Average Activation Price ($/MWh)
# 0                                      71.95
# 1                                      71.95
# 2                                      71.95
# 3                                      71.95
# 4                                      71.95
# Dataframe Name: aeso_ASPActiveOperatingReservePrice
#    Date_Date  Regulating Reserves_On Peak  Regulating Reserves_On Peak  \
# 0 2021-03-01                      -$29.01                          130
# 1 2021-03-02                      -$31.47                          129
# 2 2021-03-03                      -$20.45                          130
# 3 2021-03-04                      -$25.29                          130
# 4 2021-03-05                      -$45.62                          129
#
#    Regulating Reserves_Off Peak  Regulating Reserves_Off Peak  \
# 0                         $3.06                           115
# 1                       -$18.37                           115
# 2                       -$20.02                           115
# 3                       -$20.07                           115
# 4                       -$23.67                           115
#
#    Regulating Reserves_Super Peak AM  Regulating Reserves_Super Peak AM  \
# 0                            -$16.52                                 25
# 1                            -$15.50                                 25
# 2                            -$16.66                                 25
# 3                            -$17.54                                 25
# 4                            -$24.10                                 25
#
#    Regulating Reserves_Super Peak PM  Regulating Reserves_Super Peak PM  \
# 0                            -$34.57                                 20
# 1                            -$29.22                                 20
# 2                            -$29.27                                 20
# 3                            -$31.21                                 20
# 4                            -$33.94                                 20
#
#    Spinning Reserves_On Peak  Spinning Reserves_On Peak  \
# 0                    -$30.67                        317
# 1                    -$21.41                        317
# 2                    -$26.15                        317
# 3                    -$31.41                        317
# 4                    -$28.11                        315
#
#    Spinning Reserves_Off Peak  Spinning Reserves_Off Peak  \
# 0                     -$25.95                         315
# 1                     -$22.15                         315
# 2                     -$24.23                         315
# 3                     -$27.33                         307
# 4                     -$26.55                         307
#
#    Supplemental Reserves_On Peak  Supplemental Reserves_On Peak  \
# 0                        -$40.23                            317
# 1                        -$23.07                            317
# 2                        -$28.67                            317
# 3                        -$47.11                            317
# 4                       -$100.89                            311
#
#    Supplemental Reserves_Off Peak  Supplemental Reserves_Off Peak
# 0                         -$40.01                             315
# 1                         -$37.80                             315
# 2                         -$39.74                             315
# 3                         -$40.99                             307
# 4                         -$49.12                             307
# Dataframe Name: aeso_ActualForecastWMRQH
#             Date (HE)  Forecast Pool Price  Actual Posted Pool Price  \
# 0 2021-03-01 01:00:00                28.64                     26.29
# 1 2021-03-01 02:00:00                36.99                     30.44
# 2 2021-03-01 03:00:00                29.02                     28.29
# 3 2021-03-01 04:00:00                25.86                     26.76
# 4 2021-03-01 05:00:00                33.76                     30.72
#
#    Day-Ahead Forecasted AIL  Actual AIL  Forecasted & Actual AIL Difference
# 0                      9374        9649                                -275
# 1                      9275        9540                                -265
# 2                      9221        9521                                -300
# 3                      9218        9538                                -320
# 4                      9279        9562                                -283
# Dataframe Name: aeso_DailyAveragePoolPrice
#   $/MWh_Date  Daily_Average  Daily_On Peak Average  Daily_Off Peak Average  \
# 0 2021-03-12          32.93                  37.37                   32.84
# 1 2021-03-11          57.13                  62.66                   46.05
# 2 2021-03-10         120.09                 162.40                   35.48
# 3 2021-03-09         137.20                 184.23                   43.13
# 4 2021-03-08         136.46                 188.51                   32.35
#
#    30Ravg_Average  30Ravg_On Peak Average  30Ravg_Off Peak Average
# 0          110.80                  133.94                    64.81
# 1          125.89                  155.25                    67.17
# 2          133.36                  166.04                    67.98
# 3          143.62                  178.80                    73.25
# 4          144.53                  180.20                    73.19
# Dataframe Name: aeso_HistoricalSystemMarginalPrice
#             Date (HE)   Time  Price ($)
# 0 2021-03-11 00:00:00  23:12      34.08
# 1 2021-03-11 00:00:00  23:00      36.39
# 2 2021-03-11 23:00:00  22:47      35.82
# 3 2021-03-11 23:00:00  22:27      36.39
# 4 2021-03-11 23:00:00  22:00      36.55
# Dataframe Name: aeso_RegulatingReserves
#         Date  HE  Avg Energy per cent  Instantaneous Min per cent  \
# 0 2021-03-01   1                   18                           4
# 1 2021-03-01   2                   46                           7
# 2 2021-03-01   3                   47                          14
# 3 2021-03-01   4                   62                           9
# 4 2021-03-01   5                   43                          10
#
#    Instantaneous Max per cent  Avg. Regulating Reserve Range (MW)
# 0                          62                               116.0
# 1                          84                               116.0
# 2                          82                               116.0
# 3                          97                               116.0
# 4                         100                               116.0

# %%
weather_hourly.head()
# Out:
#          Date/Time (LST)  Month  Day  Temp (°C)  Dew Point Temp (°C)  \
# 1416 2021-03-01 00:00:00      3    1        6.2                 -7.0
# 1417 2021-03-01 01:00:00      3    1        6.4                 -6.8
# 1418 2021-03-01 02:00:00      3    1        6.3                 -7.0
# 1419 2021-03-01 03:00:00      3    1        3.5                 -6.2
# 1420 2021-03-01 04:00:00      3    1        0.7                 -5.7
#
#       Rel Hum (%)  Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  \
# 1416         38.0                27.0             35.0             16.1
# 1417         38.0                27.0             30.0             16.1
# 1418         38.0                28.0             11.0             16.1
# 1419         49.0                22.0             11.0             16.1
# 1420         62.0                18.0             15.0             16.1
#
#       Stn Press (kPa)  Wind Chill
# 1416            88.44         0.0
# 1417            88.44         0.0
# 1418            88.49         0.0
# 1419            88.48         0.0
# 1420            88.40         0.0

# %%
weather_daily.head()
# Out:
#     Date/Time  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 59 2021-03-01      3    1          10.20            0.1            5.20
# 60 2021-03-02      3    2           6.40           -3.6            1.40
# 61 2021-03-03      3    3           8.60           -3.3            2.70
# 62 2021-03-04      3    4          10.80           -4.9            3.00
# 63 2021-03-05      3    5           8.25           -3.6            2.35
#
#     Heat Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  \
# 59               12.80              0.0              0.0                0.0
# 60               16.60              0.0              0.0                0.0
# 61               15.30              0.0              0.0                0.0
# 62               15.00              0.0              0.0                0.0
# 63               15.65              0.0              0.0                0.0
#
#     Snow on Grnd (cm)  Dir of Max Gust (10s deg)  Spd of Max Gust (km/h)
# 59                9.0                       26.0                    61.0
# 60                8.0                       20.0                    37.0
# 61                6.0                        0.0                     0.0
# 62                4.0                        0.0                     0.0
# 63                4.0                       19.0                    48.0
